# %%
import math
import os

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler

os.environ["KERAS_BACKEND"] = "torch"
import keras as k

from keras.layers import LSTM, Dense
from keras.models import Sequential

k.backend.backend()
# Out:
# 'torch'

# %%
df = pd.read_csv("../apple_share_price.csv")
df.head()
# Out:
#         Date    Open    High     Low   Close    Volume
# 0  11-Aug-17  156.60  158.57  156.07  157.48  26257096
# 1  10-Aug-17  159.90  160.00  154.63  155.32  40804273
# 2   9-Aug-17  159.26  161.27  159.11  161.06  26131530
# 3   8-Aug-17  158.60  161.83  158.27  160.08  36205896
# 4   7-Aug-17  157.06  158.92  156.67  158.81  21870321

# %%
df1 = df.reset_index()["Close"]
df1
plt.plot(df1)
plt.show()

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
df1 = scaler.fit_transform(np.array(df1).reshape(-1, 1))
df1
##splitting dataset into train and test split
training_size = int(len(df1) * 0.65)
test_size = len(df1) - training_size
train_data, test_data = df1[0:training_size, :], df1[training_size : len(df1), :1]
print(training_size, test_size)
# Out:
# 1081 583

# %%
# convert an array of values into a dataset matrix
def create_dataset(dataset, time_step=1):
    dataX, dataY = [], []
    for i in range(len(dataset) - time_step - 1):
        a = dataset[i : (i + time_step), 0]  ###i=0, 0,1,2,3-----99   100
        dataX.append(a)
        dataY.append(dataset[i + time_step, 0])
    return np.array(dataX), np.array(dataY)

# %%
# reshape into X=t,t+1,t+2,t+3 and Y=t+4
time_step = 100
X_train, y_train = create_dataset(train_data, time_step)
X_test, ytest = create_dataset(test_data, time_step)

X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# %%
model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape=(100, 1)))
model.add(LSTM(50, return_sequences=True))
model.add(LSTM(50))
model.add(Dense(1))
model.compile(loss="mse", optimizer="adam")
model.summary()
# Out:
# /workspaces/ml-stuff/.venv/lib/python3.13/site-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 100, 50)        │        10,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 100, 50)        │        20,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_2 (LSTM)                   │ (None, 50)             │        20,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │            51 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 50,851 (198.64 KB)
#  Trainable params: 50,851 (198.64 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(
    X_train,
    y_train,
    validation_data=(X_test, ytest),
    epochs=100,
    batch_size=64,
    verbose=0,
)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 history = model.fit(
#       2     X_train,
#       3     y_train,
#       4     validation_data=(X_test, ytest),
#       5     epochs=100,
#       6     batch_size=64,
#       7     verbose=0,
#       8 )
#
# File /workspaces/ml-stuff/.venv/lib/python3.13/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /workspaces/ml-stuff/.venv/lib/python3.13/site-packages/keras/src/backend/torch/trainer.py:285, in TorchTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     275 if getattr(self, "_eval_epoch_iterator", None) is None:
#     276     self._eval_epoch_iterator = TorchEpochIterator(
#     277         x=val_x,
#     278         y=val_y,
#    (...)
#     283         shuffle=False,
#     284     )
# --> 285 val_logs = self.evaluate(
#     286     x=val_x,
#     287     y=val_y,
#     288     sample_weight=val_sample_weight,
#     289     batch_size=validation_batch_size or batch_size,
#     290     steps=validation_steps,
#     291     callbacks=callbacks,
#     292     return_dict=True,
#     293     _use_cached_eval_dataset=True,
#     294 )
#     295 val_logs = {
#     296     "val_" + name: val for name, val in val_logs.items()
#     297 }
#     298 epoch_logs.update(val_logs)
#
# File /workspaces/ml-stuff/.venv/lib/python3.13/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /workspaces/ml-stuff/.venv/lib/python3.13/site-packages/keras/src/backend/torch/trainer.py:374, in TorchTrainer.evaluate(self, x, y, batch_size, verbose, sample_weight, steps, callbacks, return_dict, **kwargs)
#     372 for step, data in epoch_iterator:
#     373     callbacks.on_test_batch_begin(step)
# --> 374     logs = self.test_function(data)
#     375     callbacks.on_test_batch_end(step, logs)
#     376     if self.stop_evaluating:
#
# File /workspaces/ml-stuff/.venv/lib/python3.13/site-packages/keras/src/backend/torch/trainer.py:138, in TorchTrainer.make_test_function.<locals>.one_step_on_data(data)
#     136 data = data[0]
#     137 with torch.no_grad():
# --> 138     return self.test_step(data)
#
# File /workspaces/ml-stuff/.venv/lib/python3.13/site-packages/keras/src/backend/torch/trainer.py:85, in TorchTrainer.test_step(self, data)
#      79 (
#      80     x,
#      81     y,
#      82     sample_weight,
#      83 ) = data_adapter_utils.unpack_x_y_sample_weight(data)
#      84 if self._call_has_training_arg:
# ---> 85     y_pred = self(x, training=False)
#      86 else:
#      87     y_pred = self(x)
#
# File /workspaces/ml-stuff/.venv/lib/python3.13/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /workspaces/ml-stuff/.venv/lib/python3.13/site-packages/keras/src/layers/layer.py:899, in Layer.__call__(self, *args, **kwargs)
#     897         outputs = super().__call__(*args, **kwargs)
#     898 else:
# --> 899     outputs = super().__call__(*args, **kwargs)
#     900 # Change the layout for the layer output if needed.
#     901 # This is useful for relayout intermediate tensor in the model
#     902 # to achieve the optimal performance.
#     903 distribution = distribution_lib.distribution()
#
# File /workspaces/ml-stuff/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File /workspaces/ml-stuff/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File /workspaces/ml-stuff/.venv/lib/python3.13/site-packages/keras/src/backend/torch/layer.py:44, in TorchLayer.forward(self, *args, **kwargs)
#      43 def forward(self, *args, **kwargs):
# ---> 44     return Operation.__call__(self, *args, **kwargs)
#
# File /workspaces/ml-stuff/.venv/lib/python3.13/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /workspaces/ml-stuff/.venv/lib/python3.13/site-packages/keras/src/ops/operation.py:46, in Operation.__call__(self, *args, **kwargs)
#      41             call_fn = self.call
#      42     call_fn = traceback_utils.inject_argument_info_in_traceback(
#      43         call_fn,
#      44         object_name=(f"{self.__class__.__name__}.call()"),
#      45     )
# ---> 46     return call_fn(*args, **kwargs)
#      48 # Plain flow.
#      49 if any_symbolic_tensors(args, kwargs):
#
# File /workspaces/ml-stuff/.venv/lib/python3.13/site-packages/keras/src/utils/traceback_utils.py:156, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#     154 bound_signature = None
#     155 try:
# --> 156     return fn(*args, **kwargs)
#     157 except Exception as e:
#     158     if hasattr(e, "_keras_call_info_injected"):
#     159         # Only inject info for the innermost failing call
#
# File /workspaces/ml-stuff/.venv/lib/python3.13/site-packages/keras/src/models/sequential.py:213, in Sequential.call(self, inputs, training, mask)
#     211 def call(self, inputs, training=None, mask=None):
#     212     if self._functional:
# --> 213         return self._functional.call(inputs, training=training, mask=mask)
#     215     # Fallback: Just apply the layer sequence.
#     216     # This typically happens if `inputs` is a nested struct.
#     217     for layer in self.layers:
#     218         # During each iteration, `inputs` are the inputs to `layer`, and
#     219         # `outputs` are the outputs of `layer` applied to `inputs`. At the
#     220         # end of each iteration `inputs` is set to `outputs` to prepare for
#     221         # the next layer.
#
# File /workspaces/ml-stuff/.venv/lib/python3.13/site-packages/keras/src/models/functional.py:182, in Functional.call(self, inputs, training, mask)
#     180         if mask is not None:
#     181             backend.set_keras_mask(x, mask)
# --> 182 outputs = self._run_through_graph(
#     183     inputs, operation_fn=lambda op: operation_fn(op, training=training)
#     184 )
#     185 return unpack_singleton(outputs)
#
# File /workspaces/ml-stuff/.venv/lib/python3.13/site-packages/keras/src/ops/function.py:171, in Function._run_through_graph(self, inputs, operation_fn, call_fn)
#     169     outputs = call_fn(op, *args, **kwargs)
#     170 else:
# --> 171     outputs = op(*args, **kwargs)
#     173 # Update tensor_dict.
#     174 for x, y in zip(node.outputs, tree.flatten(outputs)):
#
# File /workspaces/ml-stuff/.venv/lib/python3.13/site-packages/keras/src/models/functional.py:632, in operation_fn.<locals>.call(*args, **kwargs)
#     626 if (
#     627     hasattr(operation, "_call_has_training_arg")
#     628     and operation._call_has_training_arg
#     629     and training is not None
#     630 ):
#     631     kwargs["training"] = training
# --> 632 return operation(*args, **kwargs)
#
# File /workspaces/ml-stuff/.venv/lib/python3.13/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /workspaces/ml-stuff/.venv/lib/python3.13/site-packages/keras/src/layers/layer.py:899, in Layer.__call__(self, *args, **kwargs)
#     897         outputs = super().__call__(*args, **kwargs)
#     898 else:
# --> 899     outputs = super().__call__(*args, **kwargs)
#     900 # Change the layout for the layer output if needed.
#     901 # This is useful for relayout intermediate tensor in the model
#     902 # to achieve the optimal performance.
#     903 distribution = distribution_lib.distribution()
#
# File /workspaces/ml-stuff/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File /workspaces/ml-stuff/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File /workspaces/ml-stuff/.venv/lib/python3.13/site-packages/keras/src/backend/torch/layer.py:44, in TorchLayer.forward(self, *args, **kwargs)
#      43 def forward(self, *args, **kwargs):
# ---> 44     return Operation.__call__(self, *args, **kwargs)
#
# File /workspaces/ml-stuff/.venv/lib/python3.13/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /workspaces/ml-stuff/.venv/lib/python3.13/site-packages/keras/src/ops/operation.py:46, in Operation.__call__(self, *args, **kwargs)
#      41             call_fn = self.call
#      42     call_fn = traceback_utils.inject_argument_info_in_traceback(
#      43         call_fn,
#      44         object_name=(f"{self.__class__.__name__}.call()"),
#      45     )
# ---> 46     return call_fn(*args, **kwargs)
#      48 # Plain flow.
#      49 if any_symbolic_tensors(args, kwargs):
#
# File /workspaces/ml-stuff/.venv/lib/python3.13/site-packages/keras/src/utils/traceback_utils.py:156, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#     154 bound_signature = None
#     155 try:
# --> 156     return fn(*args, **kwargs)
#     157 except Exception as e:
#     158     if hasattr(e, "_keras_call_info_injected"):
#     159         # Only inject info for the innermost failing call
#
# File /workspaces/ml-stuff/.venv/lib/python3.13/site-packages/keras/src/layers/rnn/lstm.py:570, in LSTM.call(self, sequences, initial_state, mask, training)
#     569 def call(self, sequences, initial_state=None, mask=None, training=False):
# --> 570     return super().call(
#     571         sequences, mask=mask, training=training, initial_state=initial_state
#     572     )
#
# File /workspaces/ml-stuff/.venv/lib/python3.13/site-packages/keras/src/layers/rnn/rnn.py:402, in RNN.call(self, sequences, initial_state, mask, training)
#     396 # Prepopulate the dropout state so that the inner_loop is stateless
#     397 # this is particularly important for JAX backend.
#     398 self._maybe_config_dropout_masks(
#     399     self.cell, sequences[:, 0, :], initial_state
#     400 )
# --> 402 last_output, outputs, states = self.inner_loop(
#     403     sequences=sequences,
#     404     initial_state=initial_state,
#     405     mask=mask,
#     406     training=training,
#     407 )
#     408 last_output = ops.cast(last_output, self.compute_dtype)
#     409 outputs = ops.cast(outputs, self.compute_dtype)
#
# File /workspaces/ml-stuff/.venv/lib/python3.13/site-packages/keras/src/layers/rnn/lstm.py:565, in LSTM.inner_loop(self, sequences, initial_state, mask, training)
#     558 if self.use_cudnn is True:
#     559     raise ValueError(
#     560         "use_cudnn=True was specified, "
#     561         "but cuDNN is not supported for this layer configuration "
#     562         "with this backend. Pass use_cudnn='auto' to fallback "
#     563         "to a non-cuDNN implementation."
#     564     )
# --> 565 return super().inner_loop(
#     566     sequences, initial_state, mask=mask, training=training
#     567 )
#
# File /workspaces/ml-stuff/.venv/lib/python3.13/site-packages/keras/src/layers/rnn/rnn.py:342, in RNN.inner_loop(self, sequences, initial_state, mask, training)
#     339 if not tree.is_nested(initial_state):
#     340     initial_state = [initial_state]
# --> 342 return backend.rnn(
#     343     step,
#     344     sequences,
#     345     initial_state,
#     346     go_backwards=self.go_backwards,
#     347     mask=mask,
#     348     unroll=self.unroll,
#     349     input_length=sequences.shape[1],
#     350     zero_output_for_mask=self.zero_output_for_mask,
#     351     return_all_outputs=self.return_sequences,
#     352 )
#
# File /workspaces/ml-stuff/.venv/lib/python3.13/site-packages/keras/src/backend/torch/rnn.py:347, in rnn(step_function, inputs, initial_states, go_backwards, mask, constants, unroll, input_length, time_major, zero_output_for_mask, return_all_outputs)
#     345 new_states = states
#     346 while time < time_steps_t and it < max_iterations:
# --> 347     final_outputs = _step(time, output_ta_t, *new_states)
#     348     time, output_ta_t = final_outputs[:2]
#     349     new_states = final_outputs[2:]
#
# File /workspaces/ml-stuff/.venv/lib/python3.13/site-packages/keras/src/backend/torch/rnn.py:328, in rnn.<locals>._step(time, output_ta_t, *states)
#     326 current_input = tuple(ta[time] for ta in input_ta)
#     327 current_input = tree.pack_sequence_as(inputs, current_input)
# --> 328 output, new_states = step_function(
#     329     current_input, tuple(states) + tuple(constants)
#     330 )
#     331 flat_new_state = tree.flatten(new_states)
#     333 flat_output = tree.flatten(output)
#
# File /workspaces/ml-stuff/.venv/lib/python3.13/site-packages/keras/src/layers/rnn/rnn.py:334, in RNN.inner_loop.<locals>.step(inputs, states)
#     333 def step(inputs, states):
# --> 334     output, new_states = self.cell(inputs, states, **cell_kwargs)
#     335     if not tree.is_nested(new_states):
#     336         new_states = [new_states]
#
# File /workspaces/ml-stuff/.venv/lib/python3.13/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /workspaces/ml-stuff/.venv/lib/python3.13/site-packages/keras/src/layers/layer.py:899, in Layer.__call__(self, *args, **kwargs)
#     897         outputs = super().__call__(*args, **kwargs)
#     898 else:
# --> 899     outputs = super().__call__(*args, **kwargs)
#     900 # Change the layout for the layer output if needed.
#     901 # This is useful for relayout intermediate tensor in the model
#     902 # to achieve the optimal performance.
#     903 distribution = distribution_lib.distribution()
#
# File /workspaces/ml-stuff/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File /workspaces/ml-stuff/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File /workspaces/ml-stuff/.venv/lib/python3.13/site-packages/keras/src/backend/torch/layer.py:44, in TorchLayer.forward(self, *args, **kwargs)
#      43 def forward(self, *args, **kwargs):
# ---> 44     return Operation.__call__(self, *args, **kwargs)
#
# File /workspaces/ml-stuff/.venv/lib/python3.13/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /workspaces/ml-stuff/.venv/lib/python3.13/site-packages/keras/src/ops/operation.py:46, in Operation.__call__(self, *args, **kwargs)
#      41             call_fn = self.call
#      42     call_fn = traceback_utils.inject_argument_info_in_traceback(
#      43         call_fn,
#      44         object_name=(f"{self.__class__.__name__}.call()"),
#      45     )
# ---> 46     return call_fn(*args, **kwargs)
#      48 # Plain flow.
#      49 if any_symbolic_tensors(args, kwargs):
#
# File /workspaces/ml-stuff/.venv/lib/python3.13/site-packages/keras/src/utils/traceback_utils.py:156, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#     154 bound_signature = None
#     155 try:
# --> 156     return fn(*args, **kwargs)
#     157 except Exception as e:
#     158     if hasattr(e, "_keras_call_info_injected"):
#     159         # Only inject info for the innermost failing call
#
# File /workspaces/ml-stuff/.venv/lib/python3.13/site-packages/keras/src/layers/rnn/lstm.py:266, in LSTMCell.call(self, inputs, states, training)
#     263 else:
#     264     z = ops.matmul(inputs, self.kernel)
# --> 266     z += ops.matmul(h_tm1, self.recurrent_kernel)
#     267     if self.use_bias:
#     268         z += self.bias
#
# File /workspaces/ml-stuff/.venv/lib/python3.13/site-packages/keras/src/ops/numpy.py:3759, in matmul(x1, x2)
#    3757 if any_symbolic_tensors((x1, x2)):
#    3758     return Matmul().symbolic_call(x1, x2)
# -> 3759 return backend.numpy.matmul(x1, x2)
#
# File /workspaces/ml-stuff/.venv/lib/python3.13/site-packages/keras/src/backend/torch/numpy.py:114, in matmul(x1, x2)
#     112 x1 = cast(x1, compute_dtype)
#     113 x2 = cast(x2, compute_dtype)
# --> 114 return cast(torch.matmul(x1, x2), result_dtype)
#
# KeyboardInterrupt:

# %%
# Show the learning curves
history_df = pd.DataFrame(history.history)
history_df.loc[:, ["loss", "val_loss"]].plot();

# %%
train_predict = model.predict(X_train)  # prediction
test_predict = model.predict(X_test)
# Out:
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 4s 119ms/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 131ms/step

# %%
##Transformback to original form
train_predict = scaler.inverse_transform(train_predict)
test_predict = scaler.inverse_transform(test_predict)

# %%
# Calculate RMSE performance metrics
print(math.sqrt(mean_squared_error(y_train, train_predict)))
print(math.sqrt(mean_squared_error(ytest, test_predict)))
# Out:
# 103.03825290751618
# 69.3203027812169

# %%
# shift train predictions for plotting
look_back = 100
trainPredictPlot = np.empty_like(df1)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back : len(train_predict) + look_back, :] = train_predict
# shift test predictions for plotting
testPredictPlot = np.empty_like(df1)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(train_predict) + (look_back * 2) + 1 : len(df1) - 1, :] = (
    test_predict
)
# plot baseline and predictions
plt.plot(scaler.inverse_transform(df1))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.legend()
plt.show()
# Out:
# /tmp/ipykernel_17256/4266364799.py:16: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
x_input = test_data[483:].reshape(1, -1)  # len(test_data)
temp_input = list(x_input)
temp_input = temp_input[0].tolist()

# %%
# demonstrate prediction for next 10 days
lst_output = []
n_steps = 100
i = 0
while i < 30:
    if len(temp_input) > 100:
        # print(temp_input)
        x_input = np.array(temp_input[1:])
        # print("{} day input {}".format(i, x_input))
        x_input = x_input.reshape(1, -1)
        x_input = x_input.reshape((1, n_steps, 1))
        # print(x_input)
        yhat = model.predict(x_input, verbose=0)
        # print("{} day output {}".format(i, yhat))
        temp_input.extend(yhat[0].tolist())
        temp_input = temp_input[1:]
        # print(temp_input)
        lst_output.extend(yhat.tolist())
        i = i + 1
    else:
        x_input = x_input.reshape((1, n_steps, 1))
        yhat = model.predict(x_input, verbose=0)
        # print(yhat[0])
        temp_input.extend(yhat[0].tolist())
        # print(len(temp_input))
        lst_output.extend(yhat.tolist())
        i = i + 1


# print(lst_output)

day_new = np.arange(1, 101)
day_pred = np.arange(101, 131)
plt.plot(day_new, scaler.inverse_transform(df1[1564:]))  # len(df1)
plt.plot(day_pred, scaler.inverse_transform(lst_output))

# %%
df3 = df1.tolist()
df3.extend(lst_output)
df3 = scaler.inverse_transform(df3).tolist()
plt.plot(df3[1600:])
plt.plot(df3)

# %%
plt.plot(df3)
