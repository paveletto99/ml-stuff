# %%
SERVER_URL = 'https://fortifyssc.fmcgds.com'

SSC_REST_TOKEN = 'MmM5NTVjZDktNmJlOS00MzQ2LTlmY2YtMzZkOGJlMTJiOWQz'
TOKEN = '2c955cd9-6be9-4346-9fcf-36d8be12b9d3'


https://fortifyssc.fmcgds.com/ssc/html/docs/auth


'/api/v1/tokens'
